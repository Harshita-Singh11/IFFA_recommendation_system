# %%
import pandas as pd

# %%
df = pd.read_csv("Movie_list.csv")
df.head()
# Out:
#    Unnamed: 0        Project Title  Poster     Country Tracking Number  \
# 0           0                SCARS      NaN  Australia        IFFA1001
# 1           1              The Cut      NaN  Australia        IFFA1002
# 2           2           Al Bangeri      NaN       Oman        IFFA1003
# 3           3               Lilith      NaN  Australia        IFFA1004
# 4           4  The Night's Takings      NaN  Australia        IFFA1005
#
#                                             Synopsis  Duration  \
# 0  A tennis sensation struggles to deal with the ...  00:07:46
# 1  A 30 years old actress Kate has stayed unemplo...  00:12:00
# 2  Haseena, the protagonist of our film, a widow ...  00:25:11
# 3  Fearing for his family’s safety after the murd...  01:32:35
# 4  A man steals the night's takings from the bar ...  00:08:14
#
#   Country of Origin Language Country of Filming  ... Aspect Ratio  \
# 0         Australia  English          Australia  ...           32
# ...

# %%
df['poster_url']=df
